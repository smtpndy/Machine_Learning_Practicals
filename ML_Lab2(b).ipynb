# %% [markdown]
# <a href="https://colab.research.google.com/github/smtpndy/Machine_Learning_Practicals/blob/main/ML_Lab2(b).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# df[df['GarageQual'] =='TA'].value_counts().plot(kind='kde',ax=ax)
df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax,color='blue')
df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')

lines,labels = ax.get_legend_handles_labels()
labels=['Licsence with TA','Issue with TA']
ax.legend(lines,labels,loc='best')

plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# df[df['GarageQual'] =='TA'].value_counts().plot(kind='kde',ax=ax)
df[df['FireplaceQu']=='TA']['SalePrice'].plot(kind='kde',ax=ax,color='blue')
df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')

lines,labels = ax.get_legend_handles_labels()
labels=['Licsence with TA','Issue with TA']
ax.legend(lines,labels,loc='best')

plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')
